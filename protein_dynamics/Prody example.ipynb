# %% [markdown]
# First do homology modeling using SWISS, Robetta, or GalaxyWeb to cread predicted pdb files - swiss 1 is a  predicted spike protein taken from the biological modeling tutorial https://biologicalmodeling.org/coronavirus/tutorial_homology

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.ion()
from pylab import *
from prody import *
from Bio import *
# Out:
# C:\Users\mkouz\AppData\Roaming\Python\Python310\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
def printMatch(match):
    print('Chain 1 : {}'.format(match[0]))
    print('Chain 2 : {}'.format(match[1]))
    print('Length : {}'.format(len(match[0])))
    print('Seq identity: {}'.format(match[2]))
    print('Seq overlap : {}'.format(match[3]))
    print('RMSD : {}\n'.format(calcRMSD(match[0], match[1])))

# %%
struct1 = parsePDB('swiss1.pdb')
# Out:
# @> 26157 atoms and 1 coordinate set(s) were parsed in 0.37s.

# %% [markdown]
# Structure of the SARS-CoV-2 spike glycoprotein (closed state)

# %%
struct2 = parsePDB('6vxx')
# Out:
# @> PDB file is found in working directory (6vxx.pdb.gz).
# @> 23694 atoms and 1 coordinate set(s) were parsed in 0.37s.

# %% [markdown]
# SARS-CoV-2 S Omicron Spike B.1.1.529

# %%
struct3 = parsePDB('7QO7')
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> Downloading PDB files via FTP failed, trying HTTP.
# @> 7qo7 downloaded (C:\Users\mkouz\...\7qo7.pdb.gz)
# @> PDB download via HTTP completed (1 downloaded, 0 failed).
# @> 26865 atoms and 1 coordinate set(s) were parsed in 0.17s.

# %% [markdown]
# # Comparison of spike protein predicted via homology modeling and model calculated via elecron microscopy

# %%
matches1 = matchChains(struct1.protein, struct2.protein, seqid = 75, overlap = 80)
# Out:
# @> Checking AtomGroup swiss1: 3 chains are identified
# @> Checking AtomGroup 6vxx: 3 chains are identified
# @> Trying to match chains based on residue numbers and names:
# @>   Comparing Chain A from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain A from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain B from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @>   Comparing Chain C from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Failed to match chains (seqid=6%, overlap=85%).
# @> Trying to match chains based on local sequence alignment:
# @>  Comparing Chain A from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain A from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain A from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain B from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain A from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain B from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.
# @>  Comparing Chain C from swiss1 (len=1120) and Chain C from 6vxx (len=972):
# @> 	Match: 971 residues match with 100% sequence identity and 87% overlap.

# %%
for match in matches1:
    printMatch(match)
# Out:
# Chain 1 : AtomMap Chain A from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 32.40892431179063
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 47.037995021072824
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 58.94181412098118
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 67.30652364236154
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 48.81581935108342
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 33.740250682476784
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 51.527440685696
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 78.60491318302446
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 42.445296947844895

# %%
for match in matches1:
    printMatch_transformed(match)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# Chain 1 : AtomMap Chain A from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 8.718049575686118
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 8.71804816988966
#
# Chain 1 : AtomMap Chain A from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain A from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 8.718046989095749
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.6712496924715077
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.67126347204953
#
# Chain 1 : AtomMap Chain B from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain B from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.671249249374239
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain A from 6vxx
# Chain 2 : AtomMap Chain A from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.3616233313048154
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain B from 6vxx
# Chain 2 : AtomMap Chain B from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.3616243068947511
#
# Chain 1 : AtomMap Chain C from swiss1 -> Chain C from 6vxx
# Chain 2 : AtomMap Chain C from 6vxx -> Chain C from swiss1
# Length : 971
# Seq identity: 99.89711934156378
# Seq overlap : 86.69642857142857
# RMSD : 1.36163078030337

# %%
first_ca = matches1[4][0]
second_ca = matches1[4][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca, second_ca)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# 1.6712634720495376

# %% [markdown]
# Calculate Root mean square deviation of Matched A,B,and C chains

# %%
first_ca = matches1[0][0] + matches1[4][0] + matches1[8][0]
second_ca = matches1 [0][1] + matches1[4][1] + matches1[8][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca, second_ca)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# 5.851843229103559

# %% [markdown]
# # Using GNM to analyze spike alpha proteins movement.

# %% [markdown]
# prep to run GNM

# %%
spike = parsePDB('6vxx')
# Out:
# @> PDB file is found in working directory (6vxx.pdb.gz).
# @> 23694 atoms and 1 coordinate set(s) were parsed in 0.16s.

# %% [markdown]
# analyzing carbon alphas on chain a

# %%
calphas = spike.select('calpha and chain A')

# %% [markdown]
# Build Kirchoff Matrix

# %%
gnm = GNM('SARS-CoV-2 Spike (6vxx) Chain A Cutoff = 20.0 A')
gnm.buildKirchhoff(calphas, cutoff=20.0)
# Out:
# @> Kirchhoff was built in 0.09s.

# %%
gnm.calcModes()
hinges = calcHinges(gnm)
# Out:
# @> 20 modes were calculated in 0.27s.

# %%
gnm.getEigvals()
gnm.getEigvecs()
gnm.getCovariance()

#To get information specifically on the slowest mode (which is always indexed at 0):
slowMode = gnm[0]
slowMode.getEigval()
slowMode.getEigvec()
# Out:
# array([ 0.00993497,  0.00982494,  0.00965129,  0.00925228,  0.00929074,
#         0.00903583,  0.00912897,  0.0094634 ,  0.00963427,  0.00950717,
#         0.00972401,  0.00978306,  0.01025901,  0.0108982 ,  0.01123671,
#         0.01223696,  0.01207616,  0.01208785,  0.01193123,  0.01219562,
#         0.01227034,  0.0107157 ,  0.01106047,  0.01040432,  0.01048678,
#         0.0100798 ,  0.00973796,  0.00955676,  0.00942604,  0.00937531,
#         0.00901174,  0.00870109,  0.00884765,  0.00900289,  0.00937169,
#         0.00960757,  0.00983166,  0.00994688,  0.01000767,  0.01008012,
#         0.01014037,  0.01019692,  0.01028778,  0.01015871,  0.0101845 ,
#         0.01018648,  0.0101834 ,  0.01008425,  0.01004491,  0.01002104,
#         0.00989753,  0.00978702,  0.00979905,  0.00980138,  0.00979183,
#         0.00993229,  0.0099057 ,  0.00999711,  0.01000378,  0.01007649,
#         0.01017813,  0.01021439,  0.01019894,  0.01019817,  0.01015056,
#         0.01020428,  0.01020131,  0.0101902 ,  0.01021889,  0.0101836 ,
#         0.01023878,  0.01026992,  0.01031066,  0.01030143,  0.0103774 ,
#         0.01038528,  0.01040482,  0.01033712,  0.0103172 ,  0.01027824,
#         0.01024223,  0.01024517,  0.01022541,  0.01024147,  0.0102376 ,
#         0.01028409,  0.01029372,  0.01030879,  0.01031687,  0.0102697 ,
#         0.01029633,  0.01027389,  0.01030583,  0.0102898 ,  0.01035315,
#         0.01036425,  0.01036258,  0.01038503,  0.01037418,  0.01038548,
#         0.01037342,  0.01032068,  0.01030836,  0.01030125,  0.0103188 ,
#         0.01035309,  0.01035736,  0.01045576,  0.01039705,  0.01037795,
#         0.01035196,  0.0103614 ,  0.01034481,  0.01036342,  0.01033945,
#         0.01004577,  0.01005306,  0.01004179,  0.00993722,  0.00995965,
#         0.00989265,  0.00992267,  0.00992512,  0.00998341,  0.01000934,
#         0.01005865,  0.01007854,  0.01027853,  0.010198  ,  0.01018358,
#         0.01014739,  0.01009288,  0.01006855,  0.00997831,  0.00995098,
#         0.0099933 ,  0.01000746,  0.00994738,  0.00997364,  0.00994758,
#         0.01000688,  0.00995859,  0.00998731,  0.0099584 ,  0.00991418,
#         0.00978431,  0.00978988,  0.00945817,  0.00932036,  0.00945254,
#         0.00976878,  0.00969969,  0.00991258,  0.00998962,  0.01006053,
#         0.01018406,  0.01019372,  0.0101911 ,  0.01026297,  0.010283  ,
#         0.01028831,  0.01029253,  0.01026268,  0.01019652,  0.01016927,
#         0.01014864,  0.01013896,  0.01016831,  0.01018189,  0.01016851,
#         0.01021236,  0.01020978,  0.0102731 ,  0.01030159,  0.01035651,
#         0.01009998,  0.0100215 ,  0.00998201,  0.00995023,  0.00988806,
#         0.00967603,  0.00968539,  0.00957451,  0.0088397 ,  0.00813003,
#         0.00764111,  0.00850259,  0.00878045,  0.00900305,  0.00970884,
#         0.00954477,  0.01010474,  0.01009138,  0.01070082,  0.0102757 ,
#         0.01031611,  0.00988971,  0.0095526 ,  0.00932052,  0.00901994,
#         0.00873896,  0.00793265,  0.00784141,  0.00572243,  0.00501458,
#         0.00567351,  0.00388621,  0.00242473,  0.00440863,  0.00566687,
#         0.00434342,  0.00494286,  0.00700481,  0.00791999,  0.00744393,
#         0.00904486,  0.00961598,  0.00967777,  0.00842332,  0.00894902,
#         0.00832611,  0.0084587 ,  0.0068295 ,  0.00509715,  0.00340859,
#         0.00426622,  0.00233403,  0.00260328,  0.00028382, -0.00543316,
#        -0.00855643, -0.01576593, -0.02021094, -0.02375003, -0.03337633,
#        -0.03466626, -0.03940798, -0.04282785, -0.04464293, -0.04638878,
#        -0.0469928 , -0.04860756, -0.04958919, -0.05012703, -0.05167605,
#        -0.05251168, -0.05375236, -0.05455271, -0.05542161, -0.05630933,
#        -0.05687019, -0.05754006, -0.05774192, -0.05791432, -0.05819844,
#        -0.05879025, -0.0589231 , -0.05973092, -0.05985331, -0.05969758,
#        -0.05979216, -0.05997385, -0.05985237, -0.06004158, -0.05986583,
#        -0.0594513 , -0.05904178, -0.05814368, -0.05763039, -0.05678322,
#        -0.05590845, -0.05401514, -0.05322311, -0.05364392, -0.053639  ,
#        -0.05466959, -0.05487378, -0.05532   , -0.05557597, -0.0565889 ,
#        -0.05697279, -0.05693965, -0.05718248, -0.05775277, -0.0587037 ,
#        -0.05896005, -0.05873963, -0.05919644, -0.05884291, -0.05800922,
#        -0.05815845, -0.05746884, -0.0574165 , -0.05643954, -0.05565356,
#        -0.05590354, -0.05590576, -0.05483928, -0.05361425, -0.05426233,
#        -0.0536141 , -0.05168749, -0.05164768, -0.05193665, -0.05311286,
#        -0.05259185, -0.05452753, -0.05574573, -0.05689611, -0.05763261,
#        -0.0582912 , -0.05882559, -0.05948352, -0.05972771, -0.05984459,
#        -0.0601281 , -0.06001807, -0.06021597, -0.05994249, -0.0595696 ,
#        -0.05950716, -0.05962465, -0.05933197, -0.05891057, -0.05888283,
#        -0.05930392, -0.0594917 , -0.05979912, -0.06014091, -0.06030655,
#        -0.05993297, -0.05970581, -0.05993869, -0.0601696 , -0.0599681 ,
#        -0.05957318, -0.05929839, -0.05883572, -0.05860417, -0.05875297,
#        -0.05791171, -0.05749422, -0.05668593, -0.05691572, -0.05745171,
#        -0.05812571, -0.05821638, -0.05903441, -0.05938066, -0.05985416,
#        -0.05990431, -0.0602667 , -0.0603797 , -0.0602555 , -0.06027212,
#        -0.06060692, -0.06106033, -0.06115449, -0.06076252, -0.06088755,
#        -0.06059985, -0.06032678, -0.06037452, -0.06030271, -0.06044747,
#        -0.0594917 , -0.05891589, -0.05889916, -0.05946293, -0.05952056,
#        -0.06011967, -0.06037917, -0.06251927, -0.06160786, -0.06105211,
#        -0.06080726, -0.06076892, -0.06066929, -0.0606846 , -0.06094029,
#        -0.06065351, -0.06103833, -0.06087287, -0.06140259, -0.06098485,
#        -0.06062478, -0.06044288, -0.06052891, -0.06034453, -0.06007725,
#        -0.05972426, -0.05939591, -0.05908947, -0.05832473, -0.05798029,
#        -0.05737195, -0.0571237 , -0.05567666, -0.05432033, -0.05283316,
#        -0.05190878, -0.04972041, -0.04998272, -0.04999476, -0.05095554,
#        -0.05238633, -0.05340206, -0.05274271, -0.05295099, -0.05293552,
#        -0.05111157, -0.04952489, -0.0477506 , -0.04667374, -0.04498723,
#        -0.0440892 , -0.04158406, -0.04084104, -0.03760281, -0.03637941,
#        -0.03434393, -0.03881205, -0.04150718, -0.04423057, -0.04616367,
#        -0.04709298, -0.04861435, -0.04907904, -0.04736405, -0.04560457,
#        -0.04285802, -0.03789448, -0.03689943, -0.03649015, -0.0399402 ,
#        -0.04057683, -0.043558  , -0.04392819, -0.0438727 , -0.04436071,
#        -0.0455705 , -0.04616566, -0.04700391, -0.04833286, -0.04881084,
#        -0.04782867, -0.04711536, -0.04636564, -0.04544869, -0.04502478,
#        -0.04309191, -0.0429442 , -0.04195178, -0.0447764 , -0.04280675,
#        -0.04365536, -0.04260258, -0.0438628 , -0.04556668, -0.04628041,
#        -0.04647801, -0.04776608, -0.04765559, -0.04707004, -0.04701006,
#        -0.04543987, -0.04499634, -0.0436166 , -0.04229956, -0.04014888,
#        -0.03582519, -0.03343349, -0.02984071, -0.02412936, -0.01719783,
#        -0.01013336, -0.00399137, -0.00072044,  0.0004766 ,  0.00138645,
#         0.00191504,  0.00307384,  0.00438367,  0.00659691,  0.00611871,
#         0.00694835,  0.00565054,  0.00475699,  0.0049127 ,  0.00363329,
#         0.00240974,  0.00120049,  0.00062804, -0.0002535 , -0.0030007 ,
#        -0.00326965, -0.00681869, -0.00930545, -0.00969656, -0.00741403,
#        -0.01405938, -0.01655804, -0.00928388,  0.00016573, -0.00087764,
#        -0.0006254 , -0.00167849, -0.00086421, -0.00174274, -0.0012814 ,
#        -0.00258198, -0.00249923, -0.0001473 ,  0.00014424,  0.00068962,
#         0.00103985,  0.00110176,  0.00092557,  0.00186524,  0.00209934,
#         0.00266426,  0.00298605,  0.00326383,  0.00474575,  0.00418995,
#         0.00495842,  0.00408696,  0.00287381,  0.00113143,  0.00037281,
#         0.00042338,  0.00119213,  0.00131504,  0.0020231 ,  0.00229189,
#         0.00329753,  0.00314184,  0.00298652,  0.00277712,  0.00288644,
#         0.00293814,  0.00267201,  0.00227116,  0.00173644,  0.00151851,
#         0.00163197,  0.0017758 ,  0.00256813,  0.00397697,  0.005773  ,
#         0.00800696,  0.01138162,  0.01282724,  0.02044973,  0.02256993,
#         0.02673743,  0.02827253,  0.02909076,  0.02987048,  0.03046698,
#         0.03059494,  0.03020672,  0.02991826,  0.02940482,  0.02928894,
#         0.0287948 ,  0.02902616,  0.02846087,  0.02793351,  0.02750473,
#         0.02716479,  0.02677141,  0.02623948,  0.02575652,  0.02545626,
#         0.02519032,  0.02489756,  0.0246107 ,  0.02403221,  0.02399409,
#         0.02362629,  0.02307794,  0.02278768,  0.02264547,  0.02203193,
#         0.02174201,  0.02126081,  0.0211199 ,  0.02094179,  0.02083852,
#         0.02080147,  0.02080168,  0.02066437,  0.02065875,  0.02064402,
#         0.02062079,  0.02059904,  0.02075318,  0.02066513,  0.02061338,
#         0.02069838,  0.02081961,  0.02069449,  0.02074583,  0.02098789,
#         0.02105737,  0.02102132,  0.02128014,  0.02137685,  0.02118663,
#         0.02097587,  0.02132892,  0.02157022,  0.02135205,  0.02147335,
#         0.02193746,  0.02187514,  0.02181375,  0.02215674,  0.02252502,
#         0.02246861,  0.0225793 ,  0.02318175,  0.02337562,  0.02344377,
#         0.02382332,  0.02425695,  0.02412145,  0.02441261,  0.0247955 ,
#         0.02498684,  0.02503048,  0.02524197,  0.02541689,  0.02560444,
#         0.02577166,  0.02598669,  0.02600217,  0.02601178,  0.02619321,
#         0.02623104,  0.02637292,  0.02656798,  0.02660301,  0.02677381,
#         0.02666209,  0.02697354,  0.02687774,  0.02711   ,  0.02706012,
#         0.02685696,  0.02657283,  0.02637993,  0.02624725,  0.02589889,
#         0.02584873,  0.02606503,  0.02588437,  0.0259304 ,  0.02606779,
#         0.0260006 ,  0.02579409,  0.02552552,  0.02548686,  0.02559383,
#         0.0253682 ,  0.0255651 ,  0.02547169,  0.02540147,  0.02509388,
#         0.02491362,  0.02491088,  0.02473327,  0.0244646 ,  0.02441958,
#         0.02306706,  0.02327477,  0.02208286,  0.01998125,  0.02004644,
#         0.02023838,  0.02096042,  0.02116668,  0.02157518,  0.02211886,
#         0.02248454,  0.02313869,  0.02360964,  0.02416575,  0.02458747,
#         0.02461764,  0.02462568,  0.02510967,  0.02514981,  0.02503558,
#         0.02532701,  0.02566128,  0.02556367,  0.02563927,  0.02585729,
#         0.02590616,  0.02593177,  0.02608417,  0.02618118,  0.02630737,
#         0.02637483,  0.02650478,  0.0266072 ,  0.02669446,  0.02669224,
#         0.0266359 ,  0.02665029,  0.02646619,  0.02633958,  0.02655071,
#         0.02654615,  0.02665586,  0.02663268,  0.02679872,  0.02684424,
#         0.02703253,  0.0271107 ,  0.02694822,  0.02718238,  0.02725791,
#         0.02699761,  0.0271026 ,  0.02749686,  0.02737504,  0.02724924,
#         0.02752474,  0.02787107,  0.02754876,  0.02779518,  0.02842316,
#         0.02838922,  0.02862177,  0.02820941,  0.02858169,  0.02838931,
#         0.02780863,  0.02792067,  0.0281738 ,  0.02799335,  0.02761002,
#         0.02757432,  0.02760664,  0.02735076,  0.02710911,  0.02720493,
#         0.02714117,  0.02686328,  0.02662084,  0.02655665,  0.02630552,
#         0.02608888,  0.0259749 ,  0.0258233 ,  0.02563731,  0.02541424,
#         0.02527021,  0.02492053,  0.02496074,  0.02491086,  0.02234353,
#         0.02051042,  0.02017376,  0.01852667,  0.02186591,  0.02311216,
#         0.02043088,  0.02216108,  0.02344733,  0.02132268,  0.02005565,
#         0.02193438,  0.02184333,  0.01936031,  0.01961499,  0.02127618,
#         0.01990617,  0.01818671,  0.0197004 ,  0.02028997,  0.01807487,
#         0.01755673,  0.01965235,  0.01904627,  0.01737187,  0.01856179,
#         0.01906939,  0.01760928,  0.01810226,  0.01918233,  0.01993994,
#         0.02008281,  0.0203142 ,  0.01948266,  0.01897282,  0.01915117,
#         0.0192902 ,  0.02035358,  0.02008457,  0.01973758,  0.02035159,
#         0.02055939,  0.0203921 ,  0.02055467,  0.0205578 ,  0.02073738,
#         0.02074163,  0.02074286,  0.02068379,  0.02060758,  0.02062229,
#         0.02060418,  0.0205352 ,  0.02057524,  0.02060592,  0.02055191,
#         0.02055962,  0.02062793,  0.02064834,  0.02060287,  0.02068775,
#         0.02074901,  0.02077854,  0.02083187,  0.02098661,  0.02108027,
#         0.0210828 ,  0.02108312,  0.02152107,  0.0216438 ,  0.02159887,
#         0.02196582,  0.02221613,  0.02224644,  0.02253447,  0.0227776 ,
#         0.02299715,  0.02321142,  0.02344934,  0.02358334,  0.02400536,
#         0.02416015,  0.02435649,  0.02466073,  0.02496606,  0.02505911,
#         0.02527687,  0.02559991,  0.02563436,  0.02574192,  0.02594346,
#         0.02615944,  0.02615058,  0.0261359 ,  0.02622359,  0.0264543 ,
#         0.02670948,  0.02668298,  0.02714271,  0.02666835,  0.02692419,
#         0.02599461,  0.02610065,  0.0260813 ,  0.02593253,  0.02592705,
#         0.02680715,  0.02740806,  0.02703024,  0.02694729,  0.02662646,
#         0.02619708,  0.02601145,  0.02552223,  0.02524935,  0.02492523,
#         0.02460922,  0.02412191,  0.02394966,  0.02429908,  0.024846  ,
#         0.02509303,  0.02541814,  0.02576653,  0.02601416,  0.02660103,
#         0.0268946 ,  0.02735494,  0.02740403,  0.02787679,  0.02759553,
#         0.02814096,  0.02862371,  0.02950886,  0.0298827 ,  0.03012106,
#         0.03045819,  0.03062283,  0.03087665,  0.0309224 ,  0.03109265,
#         0.03121246,  0.03138557,  0.03156657,  0.03177679,  0.03171964,
#         0.03164277,  0.03142889,  0.03133261,  0.0310623 ,  0.03076906,
#         0.03072482,  0.03026731,  0.03008198,  0.03037793,  0.03064908,
#         0.03057048,  0.03071203,  0.03053115,  0.03076154,  0.03091321,
#         0.03093652,  0.03099388,  0.03076244,  0.03055235,  0.03005828,
#         0.02968877,  0.02940249,  0.02880136,  0.0289374 ,  0.02940782,
#         0.02975139,  0.03014747,  0.03043527,  0.03090739,  0.03101445,
#         0.03129796,  0.0315279 ,  0.03112986,  0.03086505,  0.03106002,
#         0.03137178,  0.03153124,  0.03161928,  0.03172342,  0.03164119,
#         0.03156489,  0.03193189,  0.03185584,  0.03146444,  0.03137968,
#         0.03115792,  0.03119013,  0.03119013,  0.03136121,  0.03130606,
#         0.03151248,  0.03150323,  0.03160681,  0.03169745,  0.03180945,
#         0.03221664,  0.03230283,  0.03281377,  0.03301017,  0.0332283 ,
#         0.0332283 ,  0.03415966])

# %%
plt.figure()
showContactMap(gnm);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
showCrossCorr(gnm);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
showMode(gnm[0], hinges=True)
grid();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Slow mode shape plot shows where protein movement changes in relative directions,

# %% [markdown]
# # Comparison of spike protein of sars Cov-2 and omicron variant

# %%
matches2 = matchChains(struct2.protein, struct3.protein, seqid = 75, overlap = 80)
# Out:
# @> Checking AtomGroup 6vxx: 3 chains are identified
# @> Checking AtomGroup 7QO7: 3 chains are identified
# @> Trying to match chains based on residue numbers and names:
# @>   Comparing Chain A from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain A from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain A from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain B from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain B from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain B from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain C from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain C from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @>   Comparing Chain C from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Failed to match chains (seqid=10%, overlap=88%).
# @> Trying to match chains based on local sequence alignment:
# @>  Comparing Chain A from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.
# @>  Comparing Chain A from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Match: 971 residues match with 97% sequence identity and 89% overlap.
# @>  Comparing Chain A from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.
# @>  Comparing Chain B from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.
# @>  Comparing Chain B from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Match: 971 residues match with 97% sequence identity and 89% overlap.
# @>  Comparing Chain B from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.
# @>  Comparing Chain C from 6vxx (len=972) and Chain A from 7QO7 (len=1101):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.
# @>  Comparing Chain C from 6vxx (len=972) and Chain B from 7QO7 (len=1096):
# @> 	Match: 971 residues match with 97% sequence identity and 89% overlap.
# @>  Comparing Chain C from 6vxx (len=972) and Chain C from 7QO7 (len=1098):
# @> 	Match: 971 residues match with 97% sequence identity and 88% overlap.

# %%
for match in matches2:
    printMatch(match)
# Out:
# Chain 1 : AtomMap Chain A from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 103.30242215666873
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 90.93897205064059
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 107.65958557241954
#
# Chain 1 : AtomMap Chain A from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 95.24640766056228
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 88.0042025845103
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 94.72293953977908
#
# Chain 1 : AtomMap Chain A from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 89.32534811326586
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 88.35433834793943
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 99.71539896132631

# %%
def printMatch_transformed(match):
    print('Chain 1 : {}'.format(match[0]))
    print('Chain 2 : {}'.format(match[1]))
    print('Length : {}'.format(len(match[0])))
    print('Seq identity: {}'.format(match[2]))
    print('Seq overlap : {}'.format(match[3]))
    first_ca = match[0]
    second_ca = match[1]
    calcTransformation(first_ca, second_ca).apply(first_ca)
    print('RMSD : {}\n'.format(calcRMSD(match[0], match[1])))

# %%
for match in matches2:
    printMatch_transformed(match)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# Chain 1 : AtomMap Chain A from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 2.2711807505382144
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 2.2711741174061992
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain B from 7QO7
# Chain 2 : AtomMap Chain B from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.5948905109489
# RMSD : 2.271179042147298
#
# Chain 1 : AtomMap Chain A from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 8.772131335346229
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 8.772131095512442
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain C from 7QO7
# Chain 2 : AtomMap Chain C from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.43351548269581
# RMSD : 8.772126249601389
#
# Chain 1 : AtomMap Chain A from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain A from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 2.4914353856705325
#
# Chain 1 : AtomMap Chain B from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain B from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 2.491430130927955
#
# Chain 1 : AtomMap Chain C from 6vxx -> Chain A from 7QO7
# Chain 2 : AtomMap Chain A from 7QO7 -> Chain C from 6vxx
# Length : 971
# Seq identity: 97.32510288065843
# Seq overlap : 88.19255222524977
# RMSD : 2.491434057141897

# %%
first_ca = matches2[1][0]
second_ca = matches2[1][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca, second_ca)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# 2.4914353856705276

# %% [markdown]
# calc RMSD of combined structure

# %%
first_ca = matches2[6][0] + matches2[1][0] + matches2[5][0]
second_ca = matches2[6][1] + matches2[1][1] + matches2[5][1]
calcTransformation(first_ca, second_ca).apply(first_ca);
calcRMSD(first_ca, second_ca)
# Out:
# @> WARNING mobile is an AtomMap instance, consider assign weights=mobile.getFlags("mapped") if there are dummy atoms in mobile
# @> WARNING target is an AtomMap instance, consider assign weights=target.getFlags("mapped") if there are dummy atoms in target
# 44.45399579190614

# %% [markdown]
# We can tell that the largest difference is in chain C of 7QO7 - the omicron spike protein. From analysis in VMD and Multiseq, we know that this occurs between residuals 50 and 170, and 300 and 680

# %%
spike = parsePDB('7QO7')
# Out:
# @> PDB file is found in working directory (7qo7.pdb.gz).
# @> 26865 atoms and 1 coordinate set(s) were parsed in 0.17s.

# %%
calphas = spike.select('calpha and chain C')

# %%
gnm = GNM('SARS-CoV-2 Omicron Spike (7QO7) Chain C Cutoff = 20.0 A')
gnm.buildKirchhoff(calphas, cutoff=20.0)
# Out:
# @> Kirchhoff was built in 0.09s.

# %%
gnm.calcModes()
hinges = calcHinges(gnm)
# Out:
# @> 20 modes were calculated in 0.32s.

# %%
gnm.getEigvals()
gnm.getEigvecs()
gnm.getCovariance()

#To get information specifically on the slowest mode (which is always indexed at 0):
slowMode = gnm[0]
slowMode.getEigval()
slowMode.getEigvec()
# Out:
# array([0.00935584, 0.00937462, 0.00932327, ..., 0.03106163, 0.03145112,
#        0.03218124])

# %%
plt.figure()
showContactMap(gnm);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
showCrossCorr(gnm);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
showMode(gnm[0], hinges=True)
grid();
# Out:
# <img src="data:image/png;base64,..." width="640">
